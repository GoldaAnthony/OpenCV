# %%
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread('/content/sample_data/butterfly.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=246x205>

# %%
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread('/content/sample_data/butterfly.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=246x205>

# %%
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread('/content/sample_data/butterfly.jpg')
resize=cv2.resize(image,(300,200))
cv2_imshow(resize)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %%
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread('/content/sample_data/butterfly.jpg')
draw=cv2.rectangle(image,(0,0),(200,200),(255,0,0),5)
cv2_imshow(draw)
# Out:
# <PIL.Image.Image image mode=RGB size=246x205>

# %%
(h,w) = image.shape[:2]
center = (w // 2,h // 2)
angle = 45
scale = 1.0
rotation_matrix = cv2.getRotationMatrix2D(center,angle,scale)
rotated = cv2.warpAffine(image,rotation_matrix,(w,h))
plt.imshow(cv2.cvtColor(rotated,cv2.COLOR_BGR2RGB))
plt.title("Rotated Image(45)")
plt.show()

# %%
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread('/content/sample_data/butterfly.jpg')
flip = cv2.flip(image,0)
cv2_imshow(flip)
# Out:
# <PIL.Image.Image image mode=RGB size=246x205>

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
image=cv2.imread('/content/sample_data/butterfly.jpg')
tx, ty = 50,100
translation_matrix = np.float32([[1,0,tx],[0,1,ty]])
translated = cv2.warpAffine(image,translation_matrix,(w, h))
plt.imshow(cv2.cvtColor(translated,cv2.COLOR_BGR2RGB))
plt.title("Translated Image")
plt.show()
